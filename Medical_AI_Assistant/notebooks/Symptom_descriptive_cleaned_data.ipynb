# %% [markdown]
# # We have to clean the data before we can use it in our model
# So i will import the Symptom_description data and clean it

# %%
# Importing the libraries of python for data manipulation:
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Now reading the exact file Symptom_description.csv

# %%
data = pd.read_csv('../data/symptom_Description.csv')
data.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
data.sample(5)
# Out:
#                     Disease                                        Description
# 18              Chicken pox  Chickenpox is a highly contagious disease caus...
# 21  Urinary tract infection  Urinary tract infection: An infection of the k...
# 15      Peptic ulcer diseae  Peptic ulcer disease (PUD) is a break in the i...
# 37                Pneumonia  Pneumonia is an infection in one or both lungs...
# 27         Fungal infection  In humans, fungal infections occur when an inv...

# %% [markdown]
# ## Data is categorical

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disease      41 non-null     object
#  1   Description  41 non-null     object
# dtypes: object(2)
# memory usage: 788.0+ bytes

# %% [markdown]
# ## Printing  all the precautions for each disease

# %%
data
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                 Diabetes
# 13                                 Impetigo
# 14                             Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemorrhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
## Checking if there are any null values:
data.isnull().sum()
# Out:
# Disease        0
# Description    0
# dtype: int64

# %% [markdown]
# # No null values

# %%
data.columns
# Out:
# Index(['Disease', 'Description'], dtype='object')

# %%
# Clean 'Disease' column: lowercase + strip whitespaces
data["Disease"] = data["Disease"].str.strip().str.lower()

# Clean 'Description' column: remove leading/trailing spaces, handle NaNs
data["Description"] = data["Description"].fillna("").str.strip()

# Drop duplicates
data = data.drop_duplicates()

# Preview the cleaned data
print(data.head())
# Out:
#           Disease                                        Description
# 0   drug reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         malaria  An infectious disease caused by protozoan para...
# 2         allergy  An allergy is an immune system response to a f...
# 3  hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       psoriasis  Psoriasis is a common skin disorder that forms...

# %%
# saving the cleaned data
data.to_csv("../data/Cleaned_Symptom_description.csv", index=False)
